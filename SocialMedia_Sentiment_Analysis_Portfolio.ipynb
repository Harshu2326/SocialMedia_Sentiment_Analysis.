# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshu2326/SocialMedia_Sentiment_Analysis./blob/main/SocialMedia_Sentiment_Analysis_Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================
# SOCIAL MEDIA SENTIMENT ANALYSIS - COMPLETE NOTEBOOK
# ==========================

# Step 1: Import Libraries
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Step 2: Create Sample Dataset (simulating social media posts)
data = {
    "Post": [
        "I love the new AI update! It's amazing.",
        "This AI tool is terrible, keeps crashing.",
        "The AI update is okay, nothing special.",
        "Absolutely fantastic experience with AI!",
        "I feel neutral about the AI product.",
        "Terrible experience with AI, not happy.",
        "Best AI tool ever! Highly recommend.",
        "The AI feature could be better.",
        "Not sure if I like this new AI tool.",
        "Customer support was really helpful and nice."
    ]
}

df = pd.DataFrame(data)
print("Sample Dataset:")
display(df)

# Step 3: Perform Sentiment Analysis
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df['Sentiment'] = df['Post'].apply(get_sentiment)
print("\nSentiment Analysis Results:")
display(df)

# Step 4: Visualize Sentiment Distribution
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Sentiment', hue='Sentiment', palette='viridis', dodge=False, legend=False)
plt.title("Sentiment Distribution of Sample Social Media Posts")
plt.show()

# Step 5: Word Clouds for Positive and Negative Posts
positive_text = ' '.join(df[df['Sentiment']=='Positive']['Post'])
negative_text = ' '.join(df[df['Sentiment']=='Negative']['Post'])

# Positive WordCloud
plt.figure(figsize=(8,6))
wc_positive = WordCloud(width=600, height=400, background_color='white').generate(positive_text)
plt.imshow(wc_positive, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Words WordCloud')
plt.show()

# Negative WordCloud
plt.figure(figsize=(8,6))
wc_negative = WordCloud(width=600, height=400, background_color='white').generate(negative_text)
plt.imshow(wc_negative, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Words WordCloud')
plt.show()
# Out:
# Sample Dataset:
#                                             Post
# 0        I love the new AI update! It's amazing.
# 1      This AI tool is terrible, keeps crashing.
# 2        The AI update is okay, nothing special.
# 3       Absolutely fantastic experience with AI!
# 4           I feel neutral about the AI product.
# 5        Terrible experience with AI, not happy.
# 6           Best AI tool ever! Highly recommend.
# 7                The AI feature could be better.
# 8           Not sure if I like this new AI tool.
# 9  Customer support was really helpful and nice.
# Sentiment Analysis Results:
#                                             Post Sentiment
# 0        I love the new AI update! It's amazing.  Positive
# 1      This AI tool is terrible, keeps crashing.  Negative
# 2        The AI update is okay, nothing special.  Positive
# 3       Absolutely fantastic experience with AI!  Positive
# 4           I feel neutral about the AI product.   Neutral
# ...

# %%
# ==========================
# SOCIAL MEDIA SENTIMENT ANALYSIS - FINAL PORTFOLIO NOTEBOOK
# ==========================

# --------------------------
# Step 1: Import Libraries
# --------------------------
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import plotly.express as px

# Set Seaborn style for professional plots
sns.set_style("whitegrid")

# --------------------------
# Step 2: Create Sample Dataset
# --------------------------
data = {
    "Post": [
        "I love the new AI update! It's amazing.",
        "This AI tool is terrible, keeps crashing.",
        "The AI update is okay, nothing special.",
        "Absolutely fantastic experience with AI!",
        "I feel neutral about the AI product.",
        "Terrible experience with AI, not happy.",
        "Best AI tool ever! Highly recommend.",
        "The AI feature could be better.",
        "Not sure if I like this new AI tool.",
        "Customer support was really helpful and nice."
    ]
}

df = pd.DataFrame(data)
print("Sample Dataset:")
display(df)

# --------------------------
# Step 3: Sentiment Analysis
# --------------------------
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df['Sentiment'] = df['Post'].apply(get_sentiment)
print("\nSentiment Analysis Results:")
display(df)

# --------------------------
# Step 4: Static Sentiment Distribution Plot (Matplotlib/Seaborn)
# --------------------------
plt.figure(figsize=(8,5))
sns.countplot(
    data=df,
    x='Sentiment',
    hue='Sentiment',
    palette={'Positive':'#2ecc71', 'Negative':'#e74c3c', 'Neutral':'#f1c40f'},
    dodge=False,
    legend=False
)
plt.title("Distribution of Sentiments", fontsize=16)
plt.xlabel("Sentiment", fontsize=12)
plt.ylabel("Number of Posts", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
# Out:
# Sample Dataset:
#                                             Post
# 0        I love the new AI update! It's amazing.
# 1      This AI tool is terrible, keeps crashing.
# 2        The AI update is okay, nothing special.
# 3       Absolutely fantastic experience with AI!
# 4           I feel neutral about the AI product.
# 5        Terrible experience with AI, not happy.
# 6           Best AI tool ever! Highly recommend.
# 7                The AI feature could be better.
# 8           Not sure if I like this new AI tool.
# 9  Customer support was really helpful and nice.
# Sentiment Analysis Results:
#                                             Post Sentiment
# 0        I love the new AI update! It's amazing.  Positive
# 1      This AI tool is terrible, keeps crashing.  Negative
# 2        The AI update is okay, nothing special.  Positive
# 3       Absolutely fantastic experience with AI!  Positive
# 4           I feel neutral about the AI product.   Neutral
# ...

# %%
import plotly.express as px

# Count of each sentiment
sentiment_counts = df['Sentiment'].value_counts().reset_index()
sentiment_counts.columns = ['Sentiment', 'Count']

# Interactive bar chart
fig = px.bar(
    sentiment_counts,
    x='Sentiment',
    y='Count',
    color='Sentiment',
    color_discrete_map={'Positive':'green', 'Negative':'red', 'Neutral':'gold'},
    title='Interactive Sentiment Distribution'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(8,5))
sns.set_style("whitegrid")  # cleaner background
sns.countplot(
    data=df,
    x='Sentiment',
    hue='Sentiment',
    palette={'Positive':'#2ecc71', 'Negative':'#e74c3c', 'Neutral':'#f1c40f'},
    dodge=False,
    legend=False
)
plt.title("Distribution of Sentiments", fontsize=16)
plt.xlabel("Sentiment", fontsize=12)
plt.ylabel("Number of Posts", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()
